# %% [markdown]
# # INTRODUCTION TO THE PROBLEM
#
# * Recognizing human activities from video sequences or still images is a challenging task due to problems, such as background clutter, partial occlusion, changes in scale, viewpoint, lighting, and appearance. Many applications, including video surveillance systems, human-computer interaction, and robotics for human behavior characterization, require a multiple activity recognition system. This Walkrunclass prediction is review of recent and state-of-the-art research advances in the field of human activity classification.

# %% [markdown]
# ### In this dataset there are 6 sensors out of which 3 are gyroscopic sensors and 3 are accelerometric sensors

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/walkrun.csv")

# %%
df.shape
# Out:
# (88588, 11)

# %%
df.head()
# Out:
#         date                time username  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020   viktor      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023   viktor      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987   viktor      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985   viktor      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994   viktor      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %%
df.username.unique()
# Out:
# array(['viktor'], dtype=object)

# %% [markdown]
# # Here there is only one username and also the walk or run cant be decided using username.

# %%
df = df.drop(["username"],axis=1)

# %%
df.head()
# Out:
#         date                time  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922

# %%
df.activity.unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # 0 is Walking
# # 1 is Running

# %%
import seaborn as sns

# %%
#sns.set_style(“whitegrid”)
sns.countplot(x = df.activity)
# Out:
# <AxesSubplot:xlabel='activity', ylabel='count'>

# %% [raw]
# # Here date and time are seperated and are not in datetime class format

# %%
date_time = df.date+' '+df.time

# %%
date_time
# Out:
# 0        2017-6-30 13:51:15:847724020
# 1        2017-6-30 13:51:16:246945023
# 2        2017-6-30 13:51:16:446233987
# 3        2017-6-30 13:51:16:646117985
# 4        2017-6-30 13:51:16:846738994
#                      ...
# 88583      2017-7-9 20:9:15:317911028
# 88584      2017-7-9 20:9:15:517889022
# 88585      2017-7-9 20:9:15:717828989
# 88586      2017-7-9 20:9:15:917932987
# 88587      2017-7-9 20:9:16:117410004
# Length: 88588, dtype: object

# %%
df["date_time"] = date_time

# %%
df.head()
# Out:
#         date                time  wrist  activity  acceleration_x  \
# 0  2017-6-30  13:51:15:847724020      0         0          0.2650
# 1  2017-6-30  13:51:16:246945023      0         0          0.6722
# 2  2017-6-30  13:51:16:446233987      0         0          0.4399
# 3  2017-6-30  13:51:16:646117985      0         0          0.3031
# 4  2017-6-30  13:51:16:846738994      0         0          0.4814
#
#    acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z  \
# 0         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4         -0.9312          0.0359  0.0527  0.4379  2.4922
#
#                       date_time
# 0  2017-6-30 13:51:15:847724020
# 1  2017-6-30 13:51:16:246945023
# 2  2017-6-30 13:51:16:446233987
# 3  2017-6-30 13:51:16:646117985
# 4  2017-6-30 13:51:16:846738994

# %%
df = df.drop(["date","time"],axis=1)

# %%
df.head()
# Out:
#    wrist  activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  \
# 0      0         0          0.2650         -0.7814         -0.0076 -0.0590
# 1      0         0          0.6722         -1.1233         -0.2344 -0.1757
# 2      0         0          0.4399         -1.4817          0.0722 -0.9105
# 3      0         0          0.3031         -0.8125          0.0888  0.1199
# 4      0         0          0.4814         -0.9312          0.0359  0.0527
#
#    gyro_y  gyro_z                     date_time
# 0  0.0325 -2.9296  2017-6-30 13:51:15:847724020
# 1  0.0208  0.1269  2017-6-30 13:51:16:246945023
# 2  0.1063 -2.4367  2017-6-30 13:51:16:446233987
# 3 -0.4099 -2.9336  2017-6-30 13:51:16:646117985
# 4  0.4379  2.4922  2017-6-30 13:51:16:846738994

# %%
df = df.drop(["wrist"],axis=1)

# %%
df.head()
# Out:
#    activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  \
# 0         0          0.2650         -0.7814         -0.0076 -0.0590  0.0325
# 1         0          0.6722         -1.1233         -0.2344 -0.1757  0.0208
# 2         0          0.4399         -1.4817          0.0722 -0.9105  0.1063
# 3         0          0.3031         -0.8125          0.0888  0.1199 -0.4099
# 4         0          0.4814         -0.9312          0.0359  0.0527  0.4379
#
#    gyro_z                     date_time
# 0 -2.9296  2017-6-30 13:51:15:847724020
# 1  0.1269  2017-6-30 13:51:16:246945023
# 2 -2.4367  2017-6-30 13:51:16:446233987
# 3 -2.9336  2017-6-30 13:51:16:646117985
# 4  2.4922  2017-6-30 13:51:16:846738994

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activity        88588 non-null  int64
#  1   acceleration_x  88588 non-null  float64
#  2   acceleration_y  88588 non-null  float64
#  3   acceleration_z  88588 non-null  float64
#  4   gyro_x          88588 non-null  float64
#  5   gyro_y          88588 non-null  float64
#  6   gyro_z          88588 non-null  float64
#  7   date_time       88588 non-null  object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 5.4+ MB

# %%
df.describe()
# Out:
#            activity  acceleration_x  acceleration_y  acceleration_z  \
# count  88588.000000    88588.000000    88588.000000    88588.000000
# mean       0.500801       -0.074811       -0.562585       -0.313956
# std        0.500002        1.009299        0.658458        0.486815
# min        0.000000       -5.350500       -3.299000       -3.753800
# 25%        0.000000       -0.381800       -1.033500       -0.376000
# 50%        1.000000       -0.059500       -0.759100       -0.221000
# 75%        1.000000        0.355500       -0.241775       -0.085900
# max        1.000000        5.603300        2.668000        1.640300
#
#              gyro_x        gyro_y        gyro_z
# count  88588.000000  88588.000000  88588.000000
# mean       0.004160      0.037203      0.022327
# std        1.253423      1.198725      1.914423
# min       -4.430600     -7.464700     -9.480000
# 25%       -0.920700     -0.644825     -1.345125
# 50%        0.018700      0.039300      0.006900
# ...

# %%
df['date_time'] =  pd.to_datetime(df['date_time'], format='%Y-%m-%d %H:%M:%S:%f')

# %%
df.head()
# Out:
#    activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  \
# 0         0          0.2650         -0.7814         -0.0076 -0.0590  0.0325
# 1         0          0.6722         -1.1233         -0.2344 -0.1757  0.0208
# 2         0          0.4399         -1.4817          0.0722 -0.9105  0.1063
# 3         0          0.3031         -0.8125          0.0888  0.1199 -0.4099
# 4         0          0.4814         -0.9312          0.0359  0.0527  0.4379
#
#    gyro_z                     date_time
# 0 -2.9296 2017-06-30 13:51:15.847724020
# 1  0.1269 2017-06-30 13:51:16.246945023
# 2 -2.4367 2017-06-30 13:51:16.446233987
# 3 -2.9336 2017-06-30 13:51:16.646117985
# 4  2.4922 2017-06-30 13:51:16.846738994

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88588 entries, 0 to 88587
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activity        88588 non-null  int64
#  1   acceleration_x  88588 non-null  float64
#  2   acceleration_y  88588 non-null  float64
#  3   acceleration_z  88588 non-null  float64
#  4   gyro_x          88588 non-null  float64
#  5   gyro_y          88588 non-null  float64
#  6   gyro_z          88588 non-null  float64
#  7   date_time       88588 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 5.4 MB

# %%
# Checking whether data is sorted accordingly

# %%
df = df.sort_values("date_time").reset_index(drop=True)

# %%
df.head()
# Out:
#    activity  acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  \
# 0         0          0.2650         -0.7814         -0.0076 -0.0590  0.0325
# 1         0          0.6722         -1.1233         -0.2344 -0.1757  0.0208
# 2         0          0.4399         -1.4817          0.0722 -0.9105  0.1063
# 3         0          0.3031         -0.8125          0.0888  0.1199 -0.4099
# 4         0          0.4814         -0.9312          0.0359  0.0527  0.4379
#
#    gyro_z                     date_time
# 0 -2.9296 2017-06-30 13:51:15.847724020
# 1  0.1269 2017-06-30 13:51:16.246945023
# 2 -2.4367 2017-06-30 13:51:16.446233987
# 3 -2.9336 2017-06-30 13:51:16.646117985
# 4  2.4922 2017-06-30 13:51:16.846738994

# %%
df.to_csv("walkrun_clean.csv")

# %%
import seaborn as sns

# %%
sns.pairplot(df.iloc[:,1:7],hue ="activity")

# %%
# corelation
df.corr()
# Out:
#                 activity  acceleration_x  acceleration_y  acceleration_z  \
# activity        1.000000       -0.017747        0.639520       -0.192435
# acceleration_x -0.017747        1.000000       -0.265169       -0.552374
# acceleration_y  0.639520       -0.265169        1.000000        0.106220
# acceleration_z -0.192435       -0.552374        0.106220        1.000000
# gyro_x          0.040856       -0.021705        0.010549        0.035296
# gyro_y          0.012055       -0.004091        0.072170       -0.021004
# gyro_z         -0.008106       -0.060849       -0.022994        0.049621
#
#                   gyro_x    gyro_y    gyro_z
# activity        0.040856  0.012055 -0.008106
# acceleration_x -0.021705 -0.004091 -0.060849
# acceleration_y  0.010549  0.072170 -0.022994
# acceleration_z  0.035296 -0.021004  0.049621
# gyro_x          1.000000  0.094011  0.317769
# gyro_y          0.094011  1.000000  0.287244
# gyro_z          0.317769  0.287244  1.000000

# %% [markdown]
# # Checking for imbalance in the data

# %%
df.activity.value_counts()
# Out:
# 1    44365
# 0    44223
# Name: activity, dtype: int64

# %%
# Splitting into train and test

# %%
X = df.iloc[:,1:]

# %%
y = df.activity

# %%
X.head()
# Out:
#    acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z  \
# 0          0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1          0.6722         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2          0.4399         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3          0.3031         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4          0.4814         -0.9312          0.0359  0.0527  0.4379  2.4922
#
#                       date_time
# 0 2017-06-30 13:51:15.847724020
# 1 2017-06-30 13:51:16.246945023
# 2 2017-06-30 13:51:16.446233987
# 3 2017-06-30 13:51:16.646117985
# 4 2017-06-30 13:51:16.846738994

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: activity, dtype: int64

# %% [markdown]
# # Applying t-sne on the data

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)

# %%
X_tsne = tsne.fit_transform(X.iloc[:,:-1])

# %%
X_tsne
# Out:
# array([[-30.478373 ,  10.273747 ],
#        [ -4.337166 ,  11.197626 ],
#        [-33.31648  ,   8.227291 ],
#        ...,
#        [ 31.09301  ,  36.658764 ],
#        [ -6.0052667,  21.594007 ],
#        [-42.1986   ,  -2.0950441]], dtype=float32)

# %%
X_tsne = pd.DataFrame(X_tsne,columns=["TSNE1","TSNE2"])

# %%
X_tsne.head()
# Out:
#        TSNE1      TSNE2
# 0 -30.478373  10.273747
# 1  -4.337166  11.197626
# 2 -33.316479   8.227291
# 3 -30.415630  10.969406
# 4   7.276276  33.496529

# %%
sns.scatterplot(x= X_tsne.TSNE1,y = X_tsne.TSNE2,hue = df.activity)
# Out:
# <AxesSubplot:xlabel='TSNE1', ylabel='TSNE2'>

# %% [markdown]
# T-SNE IS HELPING TO SOME EXTENT IN CLUSTERING BUT STILL NOT A GOOD SIGN FOR DECIDING
